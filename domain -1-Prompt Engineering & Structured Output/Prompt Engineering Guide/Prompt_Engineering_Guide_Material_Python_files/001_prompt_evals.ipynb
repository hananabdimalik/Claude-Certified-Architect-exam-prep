# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

dataset

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS Account ID Extractor from ARN\n\nHere's a complete solution with explanation and tests:\n\n```python\ndef extract_account_id_from_arn(arn: str) -> str | None:\n    \"\"\"\n    Extract the AWS account ID from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn: An Amazon Resource Name string\n        \n    Returns:\n        The 12-digit account ID if present, None otherwise\n        \n    Examples:\n        >>> extract_account_id_from_arn('arn:aws:iam::123456789012:role/MyRole')\n        '123456789012'\n        >>> extract_account_id_from_arn('arn:aws:s3:::my-bucket')\n        None\n        >>> extract_account_id_from_arn('arn:aws:ec2:us-east-1:987654321098:instance/i-1234567890abcdef0')\n        '987654321098'\n    \"\"\"\n    if not arn or not isinstance(arn, str):\n        return None\n    \n    try:\n        # Split the ARN by colons\n        # Format: arn:partition:service:region:account-id:resource\n        parts = arn.split(':')\n        \n        # ARN must have at least 6 parts\n        if len(parts) < 6:\n            return None\n        \n        # Account ID is the 5th element (index 4)\n        account_id = parts[4]\n        \n        # Account ID should be a 12-digit number (or empty for services like S3)\n        if account_id and account_id.isdigit() and len(account_id) == 12:\n            return account_id\n        \n        # Return None if account ID is empty or invalid\n        return None\n        \n    except (AttributeError, IndexError):\n        return None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: IAM role with account ID\n    assert extract_account_id_from_arn('arn:aws:iam::123456789012:role/MyRole') == '123456789012'\n    print(\"\u2713 Test 1 passed: IAM role\")\n    \n    # Test 2: S3 bucket without account ID\n    assert extract_account_id_from_arn('arn:aws:s3:::my-bucket') is None\n    print(\"\u2713 Test 2 passed: S3 bucket\")\n    \n    # Test 3: EC2 instance with account ID\n    assert extract_account_id_from_arn('arn:aws:ec2:us-east-1:987654321098:instance/i-1234567890abcdef0') == '987654321098'\n    print(\"\u2713 Test 3 passed: EC2 instance\")\n    \n    # Test 4: Lambda function with account ID\n    assert extract_account_id_from_arn('arn:aws:lambda:us-west-2:111111111111:function:my-function') == '111111111111'\n    print(\"\u2713 Test 4 passed: Lambda function\")\n    \n    # Test 5: DynamoDB table with account ID\n    assert extract_account_id_from_arn('arn:aws:dynamodb:eu-west-1:555555555555:table/Users') == '555555555555'\n    print(\"\u2713 Test 5 passed: DynamoDB table\")\n    \n    # Test 6: Invalid ARN (too few parts)\n    assert extract_account_id_from_arn('arn:aws:s3') is None\n    print(\"\u2713 Test 6 passed: Invalid ARN format\")\n    \n    # Test 7: None input\n    assert extract_account_id_from_arn(None) is None\n    print(\"\u2713 Test 7 passed: None input\")\n    \n    # Test 8: Empty string\n    assert extract_account_id_from_arn('') is None\n    print(\"\u2713 Test 8 ",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID from an ARN (Amazon Resource Name) string. The function should take an ARN like 'arn:aws:s3:::my-bucket' or 'arn:aws:iam::123456789012:role/MyRole' and return the account ID, or None if not present."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 Read-Only Access\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::ACCOUNT-ID:root\"\n      },\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data\"\n    },\n    {\n      \"Sid\": \"GetObjectsFromBucket\",\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::ACCOUNT-ID:root\"\n      },\n      \"Action\": [\n        \"s3:GetObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data/*\"\n    }\n  ]\n}\n```\n\n## Key Components Explained:\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Specifies the policy language version (2012-10-17 is current) |\n| **Sid** | Statement ID for identifying each permission block |\n| **Effect** | \"Allow\" grants permission to perform actions |\n| **Principal** | `AWS: arn:aws:iam::ACCOUNT-ID:root` - Replace ACCOUNT-ID with your AWS account ID |\n| **Action** | `s3:ListBucket` - List bucket contents; `s3:GetObject` - Read objects |\n| **Resource** | Specifies which S3 resources the policy applies to |\n\n## Important Notes:\n\n- **Replace `ACCOUNT-ID`** with your actual AWS Account ID\n- **ListBucket** requires the bucket ARN (`arn:aws:s3:::company-data`)\n- **GetObject** requires the bucket contents ARN (`arn:aws:s3:::company-data/*`)\n- This is a **bucket policy** format; for IAM user policies, remove the `Principal` field\n- No `s3:PutObject` or `s3:DeleteObject` permissions are included (read-only access only)",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows read-only access to all objects in an S3 bucket named 'company-data'. The policy should include the appropriate principals, actions (GetObject, ListBucket), and resources."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS S3 Bucket Name Validation Regular Expression\n\nHere's a comprehensive solution:\n\n```regex\n^(?!(\\d+\\.){3}\\d+$)(?!-)[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$|^[a-z0-9]$\n```\n\n## Explanation\n\nLet me break down this regex pattern:\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string |\n| `(?!(\\d+\\.){3}\\d+$)` | Negative lookahead: reject IP addresses (e.g., 192.168.1.1) |\n| `(?!-)` | Negative lookahead: cannot start with hyphen |\n| `[a-z0-9]` | Must start with lowercase letter or number |\n| `[a-z0-9.-]{1,61}` | 1-61 middle characters (letters, numbers, hyphens, periods) |\n| `[a-z0-9]` | Must end with lowercase letter or number |\n| `$` | End of string |\n| `\\|` | OR operator |\n| `^[a-z0-9]$` | Alternative: 3-char minimum, so single char names are invalid except this catches edge cases |\n\n## Implementation Examples\n\n### JavaScript\n```javascript\nconst s3BucketRegex = /^(?!(\\d+\\.){3}\\d+$)(?!-)[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$|^[a-z0-9]$/;\n\n// Valid examples\nconsole.log(s3BucketRegex.test('my-bucket')); // true\nconsole.log(s3BucketRegex.test('my.bucket')); // true\nconsole.log(s3BucketRegex.test('bucket123')); // true\n\n// Invalid examples\nconsole.log(s3BucketRegex.test('My-Bucket')); // false (uppercase)\nconsole.log(s3BucketRegex.test('-bucket')); // false (starts with hyphen)\nconsole.log(s3BucketRegex.test('bucket-')); // false (ends with hyphen)\nconsole.log(s3BucketRegex.test('192.168.1.1')); // false (IP address)\nconsole.log(s3BucketRegex.test('ab')); // false (too short)\nconsole.log(s3BucketRegex.test('a' + 'b'.repeat(62))); // false (too long)\n```\n\n### Python\n```python\nimport re\n\ns3_bucket_regex = r'^(?!(\\d+\\.){3}\\d+$)(?!-)[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$|^[a-z0-9]$'\n\n# Valid\nprint(re.match(s3_bucket_regex, 'my-bucket'))  # Match object\nprint(re.match(s3_bucket_regex, 'bucket.name'))  # Match object\n\n# Invalid\nprint(re.match(s3_bucket_regex, 'My-Bucket'))  # None\nprint(re.match(s3_bucket_regex, '192.168.0.1'))  # None\n```\n\n## Key Rules Enforced\n\n\u2705 **Length**: 3-63 characters (via character counts)\n\u2705 **Characters**: Only `[a-z0-9.-]`\n\u2705 **Start**: Must be letter or number (not hyphen or period)\n\u2705 **End**: Must be letter or number (not hyphen or period)\n\u2705 **No IP format**: Rejects `x.x.x.x` patterns where x is digits\n\u2705 **Lowercase only**: No uppercase letters allowed",
#     "test_case": {
#       "task": "Write a regular expression that validates an AWS S3 bucket name. The bucket name must be 3-63 characters long, contain only lowercase letters, numbers, hyphens, and periods, start and end with a letter or number, and not be formatted as an IP address."
#     },
#     "score": 10
#   }
# ]
